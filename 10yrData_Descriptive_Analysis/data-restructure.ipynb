# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("EXCEL-COMBINED.xlsx", index_col=0)

# %%
data
# Out:
#                                                    Unnamed: 1 Unnamed: 2  \
# Distribution of Denue Cases per Municipalities/...        NaN        NaN
# Cavite Province, Morbidity week 1-52 (January 1...        NaN        NaN
# NaN                                                       NaN        NaN
# Municipalities /Cities                                      1        NaN
# NaN                                                    Alive        Died
# BACOOR                                                     85          0
# DASMARINAS                                                 67          0
# IMUS                                                       72          0
# GENERAL TRIAS                                              40          0
# TANZA                                                      25          0
# SILANG                                                      8          0
# TRECE MARITES CITY                                          8          0
# ...
